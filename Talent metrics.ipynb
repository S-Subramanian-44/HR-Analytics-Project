# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from tabulate import tabulate
df= pd.read_excel("D:\CIT\SEM 5\Human Resources System Developement Lab\EX 4.xlsx",sheet_name="Talent")
df.head(6)
# Out:
#        Name      HCRI  Training Score  Performance Score
# 0      Alex  0.608333              28                 84
# 1    Antony  0.558333              36                 63
# 2  Benjamin  0.566667              23                 71
# 3     chris  0.558333              35                 98
# 4      Carl  0.608333              22                 71
# 5     Canem  0.558333              31                 71

# %%
data = df.iloc[1:].drop(['Name'], axis=1)
data.isnull().sum()
data
# Out:
#         HCRI  Training Score  Performance Score
# 1   0.558333              36                 63
# 2   0.566667              23                 71
# 3   0.558333              35                 98
# 4   0.608333              22                 71
# 5   0.558333              31                 71
# 6   0.558333              29                 92
# 7   0.558333              25                 86
# 8   0.608333              33                 66
# 9   0.558333              24                 75
# 10  0.566667              31                 80
# 11  0.608333              24                 94
# 12  0.566667              23                 64
# 13  0.566667              28                 80
# 14  0.716667              27                 94
# 15  0.608333              25                 72
# 16  0.608333              32                 84
# 17  0.558333              24                 60
# 18  0.566667              31                 70
# 19  0.608333              33                 99
# 20  0.608333              29                 74
# 21  0.558333              30                 97
# 22  0.566667              34                 85
# 23  0.566667              26                 73
# 24  0.558333              32                 99
# 25  0.566667              36                 65
# 26  0.566667              23                 65
# 27  0.608333              34                 94
# 28  0.566667              19                 91
# 29  0.608333              35                 89
# 30  0.608333              27                 96
# 31  0.558333              32                 71
# 32  0.716667              27                 68

# %%
cor_matrix=data.corr()
cor_matrix
# Out:
#                        HCRI  Training Score  Performance Score
# HCRI               1.000000       -0.058465           0.119344
# Training Score    -0.058465        1.000000           0.172056
# Performance Score  0.119344        0.172056           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(22, 10))
sns.heatmap(cor_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(10)
df = pd.DataFrame({'Culture': np.random.randint(1, 5, 10),
                   'Performance rating': np.random.randint(1, 10, 10),
                   'Recruitment source': np.random.randint(1, 5, 10),
                   'Training hours': np.random.randint(1, 10, 10)})
plt.figure()
plt.bar(df['Culture'], df['Performance rating'], color='blue', alpha=0.7)
plt.xlabel('Culture')
plt.ylabel('Performance rating')
plt.title('Culture and performance rating')
plt.show()
